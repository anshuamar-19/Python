# %% [markdown]
# ## Assignment-01

# %% [markdown]
# #### In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### What is the difference between string and variable?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Describe three different data types.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### What is an expression made up of? What do all expressions do?
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### After running the following code, what does the variable bacon contain?

# %%
bacon = 22
type(bacon)
# Out:
# int

# %%
bacon + 1
type(bacon+1)
# Out:
# int

# %%
## What should the values of the following two terms be?
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
## What should the values of the following two terms be?
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# #### Why is eggs a valid variable name while 100 is invalid?
# 1. eggs is starting from alphabet but 100 is starting from numeric value.

# %% [markdown]
# #### What three functions can be used to get the integer, floating-point number, or string version of a value?
# 1. int(), float(),str()

# %% [markdown]
# #### Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# Ans: In the above expression we are concatenating string and integer. So concatenation is not working. We can concatenate string to string and integer to integer.
#
# If we need to concatenate 'I have eaten ' + 99 + ' burritos.' then we have to made our integer to string by putting it into quotations.

# %%
'I have eaten ' + '99' + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
